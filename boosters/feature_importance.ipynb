# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import cross_val_score, train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import manifold, decomposition, linear_model, ensemble, neighbors, cross_validation, metrics
# Out:
# /Users/Roman/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train = pd.read_csv("train_without_oversampling.csv")
test = pd.read_csv("test.csv")

# %%
y = train.target
train.drop(["target","client_id"], axis=1, inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170745 entries, 0 to 170744
# Data columns (total 44 columns):
# gender                  170745 non-null int64
# age                     170745 non-null int64
# credit_sum              170745 non-null float64
# credit_month            170745 non-null int64
# tariff_id               170745 non-null float64
# score_shk               170745 non-null float64
# monthly_income          170745 non-null float64
# credit_count            170745 non-null float64
# overdue_credit_count    170745 non-null float64
# high_edu                170745 non-null bool
# not_work                170745 non-null bool
# usual_workers           170745 non-null bool
# head_workers            170745 non-null bool
# have_business           170745 non-null bool
# single                  170745 non-null bool
# education_GRD           170745 non-null int64
# education_PGR           170745 non-null int64
# education_SCH           170745 non-null int64
# education_UGR           170745 non-null int64
# job_position_BIS        170745 non-null int64
# job_position_BIU        170745 non-null int64
# job_position_DIR        170745 non-null int64
# job_position_HSK        170745 non-null int64
# job_position_INP        170745 non-null int64
# job_position_INV        170745 non-null int64
# job_position_NOR        170745 non-null int64
# job_position_ONB        170745 non-null int64
# job_position_PNA        170745 non-null int64
# job_position_PNI        170745 non-null int64
# job_position_PNS        170745 non-null int64
# job_position_PNV        170745 non-null int64
# job_position_SPC        170745 non-null int64
# job_position_UMN        170745 non-null int64
# job_position_WOI        170745 non-null int64
# job_position_WRK        170745 non-null int64
# job_position_WRP        170745 non-null int64
# marital_status_DIV      170745 non-null int64
# marital_status_MAR      170745 non-null int64
# marital_status_UNM      170745 non-null int64
# marital_status_WID      170745 non-null int64
# city_mean_income        170745 non-null float64
# credit_pay              170745 non-null float64
# money_for_life          170745 non-null float64
# dif_city                170745 non-null float64
# dtypes: bool(6), float64(10), int64(28)
# memory usage: 50.5 MB

# %%
train_data, test_data, y_train, y_test = train_test_split(train, y, test_size = 0.25, stratify = y)

# %%
rf = ensemble.RandomForestClassifier(n_estimators=250, class_weight="balanced", max_features='auto', n_jobs=-1)
rf.fit(train_data, y_train)
preds = rf.predict(test_data)
print metrics.roc_auc_score(y_test, preds)
# Out:
# 0.528524842881

# %%
plt.scatter(x = np.arange(len(train_data.columns)), y=rf.feature_importances_)

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]
std = np.std([tree.feature_importances_ for tree in rf.estimators_],
             axis=0)

# %%
plt.figure(figsize=(30,6))
plt.title("Feature importances")
plt.bar(range(14), importances[indices][:14],
       color="r", yerr=std[indices][:14], align="center")
plt.xticks(range(14), train_data[indices[:14]])
plt.xlim([-1, 14])
plt.show()

# %%
plt.hist(np.diff(test.score_shk), bins=100)
# Out:
# (array([  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   2.00000000e+00,
#           1.00000000e+00,   2.00000000e+00,   3.00000000e+00,
#           2.00000000e+00,   5.00000000e+00,   5.00000000e+00,
#           9.00000000e+00,   1.60000000e+01,   2.10000000e+01,
#           2.90000000e+01,   4.70000000e+01,   3.60000000e+01,
#           6.20000000e+01,   9.20000000e+01,   1.25000000e+02,
#           1.72000000e+02,   2.09000000e+02,   2.64000000e+02,
#           3.30000000e+02,   4.36000000e+02,   4.87000000e+02,
#           5.87000000e+02,   6.85000000e+02,   8.01000000e+02,
#           9.36000000e+02,   1.07200000e+03,   1.21400000e+03,
#           1.43900000e+03,   1.55400000e+03,   1.73100000e+03,
#           1.90300000e+03,   2.12800000e+03,   2.37300000e+03,
#           2.49700000e+03,   2.66300000e+03,   2.82700000e+03,
#           3.02700000e+03,   3.19100000e+03,   3.26300000e+03,
#           3.29000000e+03,   3.26500000e+03,   3.42900000e+03,
#           3.36500000e+03,   3.38400000e+03,   3.34900000e+03,
#           3.16600000e+03,   3.10400000e+03,   3.02300000e+03,
#           2.78900000e+03,   2.68000000e+03,   2.50400000e+03,
#           2.25100000e+03,   2.08900000e+03,   1.88100000e+03,
#           1.72300000e+03,   1.47800000e+03,   1.34400000e+03,
#           1.24100000e+03,   1.06500000e+03,   9.12000000e+02,
#           7.97000000e+02,   6.84000000e+02,   6.05000000e+02,
#           4.90000000e+02,   4.05000000e+02,   3.32000000e+02,
#           2.60000000e+02,   1.90000000e+02,   1.56000000e+02,
#           1.29000000e+02,   9.20000000e+01,   7.90000000e+01,
#           4.70000000e+01,   2.40000000e+01,   1.10000000e+01,
#           1.60000000e+01,   1.40000000e+01,   8.00000000e+00,
#           5.00000000e+00,   3.00000000e+00,   5.00000000e+00,
#           2.00000000e+00,   2.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           1.00000000e+00]),
#  array([-0.888173  , -0.87170171, -0.85523042, -0.83875913, -0.82228784,
#         -0.80581655, -0.78934526, -0.77287397, -0.75640268, -0.73993139,
#         -0.7234601 , -0.70698881, -0.69051752, -0.67404623, -0.65757494,
#         -0.64110365, -0.62463236, -0.60816107, -0.59168978, -0.57521849,
#         -0.5587472 , -0.54227591, -0.52580462, -0.50933333, -0.49286204,
#         -0.47639075, -0.45991946, -0.44344817, -0.42697688, -0.41050559,
#         -0.3940343 , -0.37756301, -0.36109172, -0.34462043, -0.32814914,
#         -0.31167785, -0.29520656, -0.27873527, -0.26226398, -0.24579269,
#         -0.2293214 , -0.21285011, -0.19637882, -0.17990753, -0.16343624,
#         -0.14696495, -0.13049366, -0.11402237, -0.09755108, -0.08107979,
#         -0.0646085 , -0.04813721, -0.03166592, -0.01519463,  0.00127666,
#          0.01774795,  0.03421924,  0.05069053,  0.06716182,  0.08363311,
#          0.1001044 ,  0.11657569,  0.13304698,  0.14951827,  0.16598956,
#          0.18246085,  0.19893214,  0.21540343,  0.23187472,  0.24834601,
#          0.2648173 ,  0.28128859,  0.29775988,  0.31423117,  0.33070246,
#          0.34717375,  0.36364504,  0.38011633,  0.39658762,  0.41305891,
#          0.4295302 ,  0.44600149,  0.46247278,  0.47894407,  0.49541536,
#          0.51188665,  0.52835794,  0.54482923,  0.56130052,  0.57777181,
#          0.5942431 ,  0.61071439,  0.62718568,  0.64365697,  0.66012826,
#          0.67659955,  0.69307084,  0.70954213,  0.72601342,  0.74248471,
#          0.758956  ]),
#  <a list of 100 Patch objects>)
